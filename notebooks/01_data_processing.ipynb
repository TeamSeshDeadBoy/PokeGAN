# %% [markdown]
# # 0. Making Unstructured data structured

# %%
from pathlib import Path 
import kaggle
import os

DATA_PATH = Path("../data")
POKEMON_PATH = DATA_PATH / "pokemon"

if POKEMON_PATH.is_dir():
    print("Skipping download")
else:
    print("Downloading Data")
    # DATA_PATH.mkdir(parents=True, exist_ok=True)
    os.environ['KAGGLE_USERNAME'] = "ayyoshii" # username from the json file
    os.environ['KAGGLE_KEY'] = "b3760545daa9bcd03300ec0b08bd2c27" # key from the json file

    kaggle.api.dataset_download_files('truthisneverlinear/pokemon-generations-image-dataset/2', path=DATA_PATH, unzip=True)
# Out:
# Downloading Data

# %%
def dir_walkthrough(dir_path):
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} directories and {len(filenames)} images in {dirpath}.")

# %%
dir_walkthrough(POKEMON_PATH)
# Out:
# There are 5 directories and 0 images in ..\data\pokemon.
# There are 0 directories and 202 images in ..\data\pokemon\conquest.
# There are 3 directories and 942 images in ..\data\pokemon\icons.
# There are 0 directories and 5 images in ..\data\pokemon\icons\female.
# There are 1 directories and 737 images in ..\data\pokemon\icons\old.
# There are 0 directories and 3 images in ..\data\pokemon\icons\old\female.
# There are 0 directories and 80 images in ..\data\pokemon\icons\right.
# There are 13 directories and 0 images in ..\data\pokemon\main-sprites.
# There are 3 directories and 754 images in ..\data\pokemon\main-sprites\black-white.
# There are 2 directories and 754 images in ..\data\pokemon\main-sprites\black-white\back.
# There are 0 directories and 88 images in ..\data\pokemon\main-sprites\black-white\back\female.
# There are 1 directories and 753 images in ..\data\pokemon\main-sprites\black-white\back\shiny.
# There are 0 directories and 88 images in ..\data\pokemon\main-sprites\black-white\back\shiny\female.
# There are 0 directories and 93 images in ..\data\pokemon\main-sprites\black-white\female.
# There are 1 directories and 753 images in ..\data\pokemon\main-sprites\black-white\shiny.
# There are 0 directories and 93 images in ..\data\pokemon\main-sprites\black-white\shiny\female.
# There are 3 directories and 277 images in ..\data\pokemon\main-sprites\crystal.
# There are 1 directories and 251 images in ..\data\pokemon\main-sprites\crystal\animated.
# There are 0 directories and 251 images in ..\data\pokemon\main-sprites\crystal\animated\shiny.
# There are 1 directories and 277 images in ..\data\pokemon\main-sprites\crystal\back.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\crystal\back\shiny.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\crystal\shiny.
# There are 4 directories and 560 images in ..\data\pokemon\main-sprites\diamond-pearl.
# There are 2 directories and 561 images in ..\data\pokemon\main-sprites\diamond-pearl\back.
# There are 0 directories and 79 images in ..\data\pokemon\main-sprites\diamond-pearl\back\female.
# There are 1 directories and 560 images in ..\data\pokemon\main-sprites\diamond-pearl\back\shiny.
# There are 0 directories and 79 images in ..\data\pokemon\main-sprites\diamond-pearl\back\shiny\female.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\diamond-pearl\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\diamond-pearl\female\frame2.
# There are 0 directories and 560 images in ..\data\pokemon\main-sprites\diamond-pearl\frame2.
# There are 2 directories and 560 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\female\frame2.
# There are 0 directories and 560 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\frame2.
# There are 3 directories and 419 images in ..\data\pokemon\main-sprites\emerald.
# There are 1 directories and 415 images in ..\data\pokemon\main-sprites\emerald\animated.
# There are 0 directories and 415 images in ..\data\pokemon\main-sprites\emerald\animated\shiny.
# There are 0 directories and 419 images in ..\data\pokemon\main-sprites\emerald\frame2.
# There are 1 directories and 419 images in ..\data\pokemon\main-sprites\emerald\shiny.
# There are 0 directories and 419 images in ..\data\pokemon\main-sprites\emerald\shiny\frame2.
# There are 2 directories and 156 images in ..\data\pokemon\main-sprites\firered-leafgreen.
# There are 1 directories and 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\back.
# There are 0 directories and 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\back\shiny.
# There are 0 directories and 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\shiny.
# There are 2 directories and 277 images in ..\data\pokemon\main-sprites\gold.
# There are 1 directories and 277 images in ..\data\pokemon\main-sprites\gold\back.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\gold\back\shiny.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\gold\shiny.
# There are 4 directories and 574 images in ..\data\pokemon\main-sprites\heartgold-soulsilver.
# There are 3 directories and 570 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back.
# There are 1 directories and 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\female.
# There are 0 directories and 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\female\frame2.
# There are 0 directories and 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\frame2.
# There are 2 directories and 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny.
# There are 1 directories and 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\female.
# There are 0 directories and 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\female\frame2.
# There are 0 directories and 568 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\frame2.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\female\frame2.
# There are 0 directories and 571 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\frame2.
# There are 2 directories and 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\female\frame2.
# There are 0 directories and 568 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\frame2.
# There are 4 directories and 567 images in ..\data\pokemon\main-sprites\platinum.
# There are 3 directories and 568 images in ..\data\pokemon\main-sprites\platinum\back.
# There are 1 directories and 83 images in ..\data\pokemon\main-sprites\platinum\back\female.
# There are 0 directories and 83 images in ..\data\pokemon\main-sprites\platinum\back\female\frame2.
# There are 0 directories and 567 images in ..\data\pokemon\main-sprites\platinum\back\frame2.
# There are 2 directories and 567 images in ..\data\pokemon\main-sprites\platinum\back\shiny.
# There are 1 directories and 83 images in ..\data\pokemon\main-sprites\platinum\back\shiny\female.
# There are 0 directories and 83 images in ..\data\pokemon\main-sprites\platinum\back\shiny\female\frame2.
# There are 0 directories and 567 images in ..\data\pokemon\main-sprites\platinum\back\shiny\frame2.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\platinum\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\platinum\female\frame2.
# There are 0 directories and 567 images in ..\data\pokemon\main-sprites\platinum\frame2.
# There are 2 directories and 567 images in ..\data\pokemon\main-sprites\platinum\shiny.
# There are 1 directories and 90 images in ..\data\pokemon\main-sprites\platinum\shiny\female.
# There are 0 directories and 90 images in ..\data\pokemon\main-sprites\platinum\shiny\female\frame2.
# There are 0 directories and 567 images in ..\data\pokemon\main-sprites\platinum\shiny\frame2.
# There are 2 directories and 151 images in ..\data\pokemon\main-sprites\red-blue.
# There are 1 directories and 151 images in ..\data\pokemon\main-sprites\red-blue\back.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\red-blue\back\gray.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\red-blue\gray.
# There are 2 directories and 151 images in ..\data\pokemon\main-sprites\red-green.
# There are 1 directories and 151 images in ..\data\pokemon\main-sprites\red-green\back.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\red-green\back\gray.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\red-green\gray.
# There are 2 directories and 418 images in ..\data\pokemon\main-sprites\ruby-sapphire.
# There are 1 directories and 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\back.
# There are 0 directories and 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\back\shiny.
# There are 0 directories and 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\shiny.
# There are 2 directories and 277 images in ..\data\pokemon\main-sprites\silver.
# There are 1 directories and 277 images in ..\data\pokemon\main-sprites\silver\back.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\silver\back\shiny.
# There are 0 directories and 277 images in ..\data\pokemon\main-sprites\silver\shiny.
# There are 3 directories and 151 images in ..\data\pokemon\main-sprites\yellow.
# There are 2 directories and 151 images in ..\data\pokemon\main-sprites\yellow\back.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\yellow\back\gbc.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\yellow\back\gray.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\yellow\gbc.
# There are 0 directories and 151 images in ..\data\pokemon\main-sprites\yellow\gray.
# There are 6 directories and 0 images in ..\data\pokemon\overworld.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\down.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\down\frame2.
# There are 4 directories and 0 images in ..\data\pokemon\overworld\female.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\female\down.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\female\down\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\female\left.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\female\left\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\female\right.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\female\right\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\female\up.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\female\up\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\left.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\left\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\right.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\right\frame2.
# There are 5 directories and 0 images in ..\data\pokemon\overworld\shiny.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\shiny\down.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\shiny\down\frame2.
# There are 4 directories and 0 images in ..\data\pokemon\overworld\shiny\female.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\shiny\female\down.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\shiny\female\down\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\shiny\female\left.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\shiny\female\left\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\shiny\female\right.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\shiny\female\right\frame2.
# There are 1 directories and 12 images in ..\data\pokemon\overworld\shiny\female\up.
# There are 0 directories and 12 images in ..\data\pokemon\overworld\shiny\female\up\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\shiny\left.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\shiny\left\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\shiny\right.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\shiny\right\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\shiny\up.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\shiny\up\frame2.
# There are 1 directories and 564 images in ..\data\pokemon\overworld\up.
# There are 0 directories and 564 images in ..\data\pokemon\overworld\up\frame2.
# There are 1 directories and 851 images in ..\data\pokemon\sugimori.
# There are 0 directories and 5 images in ..\data\pokemon\sugimori\female.

# %%
import shutil
import os
import random

def dir_walkthrough_copy(path):
    # source_dir = '/path/to/source_folder'
    target_dir = path
    
    for dirpath, dirnames, filenames in os.walk(target_dir):
        print(f"Moving {len(filenames)} images in {dirpath}.")
        for file_name in filenames:
            try:
                shutil.move(os.path.join(dirpath, file_name), target_dir)
            except:
                file_name_arr = file_name.split('.')
                new_file_name = file_name_arr[0]+'-'+str(random.randrange(10000000))+'.'+file_name_arr[1]
                shutil.move(os.path.join(dirpath, file_name), target_dir / new_file_name)

# %%
dir_walkthrough_copy(POKEMON_PATH)
# Out:
# Moving 0 images in ..\data\pokemon.
# Moving 202 images in ..\data\pokemon\conquest.
# Moving 942 images in ..\data\pokemon\icons.
# Moving 5 images in ..\data\pokemon\icons\female.
# Moving 737 images in ..\data\pokemon\icons\old.
# Moving 3 images in ..\data\pokemon\icons\old\female.
# Moving 80 images in ..\data\pokemon\icons\right.
# Moving 0 images in ..\data\pokemon\main-sprites.
# Moving 754 images in ..\data\pokemon\main-sprites\black-white.
# Moving 754 images in ..\data\pokemon\main-sprites\black-white\back.
# Moving 88 images in ..\data\pokemon\main-sprites\black-white\back\female.
# Moving 753 images in ..\data\pokemon\main-sprites\black-white\back\shiny.
# Moving 88 images in ..\data\pokemon\main-sprites\black-white\back\shiny\female.
# Moving 93 images in ..\data\pokemon\main-sprites\black-white\female.
# Moving 753 images in ..\data\pokemon\main-sprites\black-white\shiny.
# Moving 93 images in ..\data\pokemon\main-sprites\black-white\shiny\female.
# Moving 277 images in ..\data\pokemon\main-sprites\crystal.
# Moving 251 images in ..\data\pokemon\main-sprites\crystal\animated.
# Moving 251 images in ..\data\pokemon\main-sprites\crystal\animated\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\crystal\back.
# Moving 277 images in ..\data\pokemon\main-sprites\crystal\back\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\crystal\shiny.
# Moving 560 images in ..\data\pokemon\main-sprites\diamond-pearl.
# Moving 561 images in ..\data\pokemon\main-sprites\diamond-pearl\back.
# Moving 79 images in ..\data\pokemon\main-sprites\diamond-pearl\back\female.
# Moving 560 images in ..\data\pokemon\main-sprites\diamond-pearl\back\shiny.
# Moving 79 images in ..\data\pokemon\main-sprites\diamond-pearl\back\shiny\female.
# Moving 90 images in ..\data\pokemon\main-sprites\diamond-pearl\female.
# Moving 90 images in ..\data\pokemon\main-sprites\diamond-pearl\female\frame2.
# Moving 560 images in ..\data\pokemon\main-sprites\diamond-pearl\frame2.
# Moving 560 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny.
# Moving 90 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\female.
# Moving 90 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\female\frame2.
# Moving 560 images in ..\data\pokemon\main-sprites\diamond-pearl\shiny\frame2.
# Moving 419 images in ..\data\pokemon\main-sprites\emerald.
# Moving 415 images in ..\data\pokemon\main-sprites\emerald\animated.
# Moving 415 images in ..\data\pokemon\main-sprites\emerald\animated\shiny.
# Moving 419 images in ..\data\pokemon\main-sprites\emerald\frame2.
# Moving 419 images in ..\data\pokemon\main-sprites\emerald\shiny.
# Moving 419 images in ..\data\pokemon\main-sprites\emerald\shiny\frame2.
# Moving 156 images in ..\data\pokemon\main-sprites\firered-leafgreen.
# Moving 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\back.
# Moving 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\back\shiny.
# Moving 156 images in ..\data\pokemon\main-sprites\firered-leafgreen\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\gold.
# Moving 277 images in ..\data\pokemon\main-sprites\gold\back.
# Moving 277 images in ..\data\pokemon\main-sprites\gold\back\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\gold\shiny.
# Moving 574 images in ..\data\pokemon\main-sprites\heartgold-soulsilver.
# Moving 570 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back.
# Moving 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\female.
# Moving 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\female\frame2.
# Moving 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\frame2.
# Moving 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny.
# Moving 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\female.
# Moving 83 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\female\frame2.
# Moving 568 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\back\shiny\frame2.
# Moving 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\female.
# Moving 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\female\frame2.
# Moving 571 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\frame2.
# Moving 569 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny.
# Moving 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\female.
# Moving 90 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\female\frame2.
# Moving 568 images in ..\data\pokemon\main-sprites\heartgold-soulsilver\shiny\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum.
# Moving 568 images in ..\data\pokemon\main-sprites\platinum\back.
# Moving 83 images in ..\data\pokemon\main-sprites\platinum\back\female.
# Moving 83 images in ..\data\pokemon\main-sprites\platinum\back\female\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\back\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\back\shiny.
# Moving 83 images in ..\data\pokemon\main-sprites\platinum\back\shiny\female.
# Moving 83 images in ..\data\pokemon\main-sprites\platinum\back\shiny\female\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\back\shiny\frame2.
# Moving 90 images in ..\data\pokemon\main-sprites\platinum\female.
# Moving 90 images in ..\data\pokemon\main-sprites\platinum\female\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\shiny.
# Moving 90 images in ..\data\pokemon\main-sprites\platinum\shiny\female.
# Moving 90 images in ..\data\pokemon\main-sprites\platinum\shiny\female\frame2.
# Moving 567 images in ..\data\pokemon\main-sprites\platinum\shiny\frame2.
# Moving 151 images in ..\data\pokemon\main-sprites\red-blue.
# Moving 151 images in ..\data\pokemon\main-sprites\red-blue\back.
# Moving 151 images in ..\data\pokemon\main-sprites\red-blue\back\gray.
# Moving 151 images in ..\data\pokemon\main-sprites\red-blue\gray.
# Moving 151 images in ..\data\pokemon\main-sprites\red-green.
# Moving 151 images in ..\data\pokemon\main-sprites\red-green\back.
# Moving 151 images in ..\data\pokemon\main-sprites\red-green\back\gray.
# Moving 151 images in ..\data\pokemon\main-sprites\red-green\gray.
# Moving 418 images in ..\data\pokemon\main-sprites\ruby-sapphire.
# Moving 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\back.
# Moving 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\back\shiny.
# Moving 419 images in ..\data\pokemon\main-sprites\ruby-sapphire\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\silver.
# Moving 277 images in ..\data\pokemon\main-sprites\silver\back.
# Moving 277 images in ..\data\pokemon\main-sprites\silver\back\shiny.
# Moving 277 images in ..\data\pokemon\main-sprites\silver\shiny.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow\back.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow\back\gbc.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow\back\gray.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow\gbc.
# Moving 151 images in ..\data\pokemon\main-sprites\yellow\gray.
# Moving 0 images in ..\data\pokemon\overworld.
# Moving 564 images in ..\data\pokemon\overworld\down.
# Moving 564 images in ..\data\pokemon\overworld\down\frame2.
# Moving 0 images in ..\data\pokemon\overworld\female.
# Moving 12 images in ..\data\pokemon\overworld\female\down.
# Moving 12 images in ..\data\pokemon\overworld\female\down\frame2.
# Moving 12 images in ..\data\pokemon\overworld\female\left.
# Moving 12 images in ..\data\pokemon\overworld\female\left\frame2.
# Moving 12 images in ..\data\pokemon\overworld\female\right.
# Moving 12 images in ..\data\pokemon\overworld\female\right\frame2.
# Moving 12 images in ..\data\pokemon\overworld\female\up.
# Moving 12 images in ..\data\pokemon\overworld\female\up\frame2.
# Moving 564 images in ..\data\pokemon\overworld\left.
# Moving 564 images in ..\data\pokemon\overworld\left\frame2.
# Moving 564 images in ..\data\pokemon\overworld\right.
# Moving 564 images in ..\data\pokemon\overworld\right\frame2.
# Moving 0 images in ..\data\pokemon\overworld\shiny.
# Moving 564 images in ..\data\pokemon\overworld\shiny\down.
# Moving 564 images in ..\data\pokemon\overworld\shiny\down\frame2.
# Moving 0 images in ..\data\pokemon\overworld\shiny\female.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\down.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\down\frame2.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\left.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\left\frame2.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\right.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\right\frame2.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\up.
# Moving 12 images in ..\data\pokemon\overworld\shiny\female\up\frame2.
# Moving 564 images in ..\data\pokemon\overworld\shiny\left.
# Moving 564 images in ..\data\pokemon\overworld\shiny\left\frame2.
# Moving 564 images in ..\data\pokemon\overworld\shiny\right.
# Moving 564 images in ..\data\pokemon\overworld\shiny\right\frame2.
# Moving 564 images in ..\data\pokemon\overworld\shiny\up.
# Moving 564 images in ..\data\pokemon\overworld\shiny\up\frame2.
# Moving 564 images in ..\data\pokemon\overworld\up.
# Moving 564 images in ..\data\pokemon\overworld\up\frame2.
# Moving 851 images in ..\data\pokemon\sugimori.
# Moving 5 images in ..\data\pokemon\sugimori\female.

# %%
def finish_preprocessing(source_path):
    source_dir = source_path
    target_dir = source_path / "raw"
    if target_dir.is_dir():
        print("RAW already created, adding")
    else:
        target_dir.mkdir(parents=True, exist_ok=True)
    
    print("Removing GIF's")
    for file_name in source_dir.glob("*.png"):
        shutil.move(file_name, target_dir)
        
    print("Moving PNG's to /raw")
    for file_name in source_dir.glob("*.gif"):
        os.remove(file_name)
        
    print("Removing 0 class")
    for file_name in target_dir.glob("0*"):
        os.remove(file_name)
        
    ### TODO: DELETE LAST non-CLASSES, DELETE EMPTY FOLDERS
        
    # print("Deleting empty folders")
    # for dirpath, dirnames, filenames in os.walk(target_dir):
    #     print(f"Moving {len(filenames)} images in {dirpath}.")
    #     for file_name in filenames:
    #         try:
    #             shutil.move(os.path.join(dirpath, file_name), target_dir)
    #         except:
    #             file_name_arr = file_name.split('.')
    #             new_file_name = file_name_arr[0]+'-'+str(random.randrange(10000000))+'.'+file_name_arr[1]
    #             shutil.move(os.path.join(dirpath, file_name), target_dir / new_file_name)

# %%
finish_preprocessing(POKEMON_PATH)
# Out:
# Removing GIF's
# Moving PNG's to /raw
# Removing 0 class

# %%
len(list((POKEMON_PATH / "raw").glob("*.png")))
# Out:
# 39180

# %% [markdown]
# ## 0.1 Preparing classes

# %%
import pandas as pd

pokemon_data = pd.read_csv(DATA_PATH / 'Pokemon.txt')
pokemon_data = pokemon_data.drop_duplicates(subset=["#"],keep="first")
pokemon_data = pokemon_data.set_index(["#"], drop=True)

# %%
def get_classes(df: pd.DataFrame):
    classes = df["Name"].unique()
    classes_to_idx = {class_name: i for i, class_name in enumerate(classes)}
    return classes, classes_to_idx

# %%
classes, classes_to_idx = get_classes(pokemon_data)

# %% [markdown]
# # 1. Structured Images to DataLoaders

# %% [markdown]
# ## 1.1 Data Class

# %%
from torch.utils.data import Dataset
from typing import Tuple, Dict, List
import torch
import re

class PokemonData(Dataset):
    def __init__(self,
                 targ_dir: str,
                 classes_df: pd.DataFrame,
                 transform=None):
        super().__init__()
        self.paths = list(Path(targ_dir).glob('*.png'))
        self.transform = transform
        self.classes, self.classes_to_idx = get_classes(classes_df)
        
    def load_image(self, index: int) -> Tuple[torch.Tensor, int]:
        image_path = self.paths[index]
        image = Image.open(image_path).convert("RGBA")
        return Image.composite(image, Image.new('RGBA', image.size, 'white'), image).convert("RGB")
    
    def __len__(self) -> int:
        return len(self.paths)
    
    def __getitem__(self, index: int) -> Tuple[torch.Tensor, int]:
        img = self.load_image(index)
        img_name = self.paths[index].name.split('.')[0]
        img_name = int(re.findall("\d+", img_name)[0])
        class_name = self.classes[img_name]
        class_idx = self.classes_to_idx[class_name]
        if self.transform:
            return self.transform(img), class_idx
        else:
            return img, class_idx

# %% [markdown]
# ## 1.2 Transformers

# %%
from torchvision.transforms import v2

image_transformer = v2.Compose([
    v2.ToImage(),
    # v2.ToDtype(torch.uint8, scale=True),
    v2.Resize(size=(128,128)),
    v2.ToDtype(torch.float32, scale=True)
])

# %%
raw_data = PokemonData(targ_dir= POKEMON_PATH / "raw",
                            transform=image_transformer,
                            classes_df=pokemon_data)

# %% [markdown]
# ## 1.3 DataLoaders

# %%
# in dataloaders
import os
from torch.utils.data import DataLoader

BATCH_SIZE = 32
NUM_WORKERS = 0

pokemon_dataloader = DataLoader(dataset=raw_data,
                                     batch_size=BATCH_SIZE,
                                     shuffle=True,
                                     num_workers=NUM_WORKERS,
                                     pin_memory=True)
